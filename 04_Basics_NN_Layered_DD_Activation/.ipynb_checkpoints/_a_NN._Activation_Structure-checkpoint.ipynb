# %% [markdown]
# Before

# %% [markdown]
# ![{A5D95A82-F7C3-412B-8118-9F57D030A11F}.png](attachment:a5ed8867-8b40-4540-9c8a-28d445389a8a.png)

# %%
After

# %% [markdown]
# ![{6F662434-5577-4241-8DF0-E3DECD2C190D}.png](attachment:77e8becb-62d7-4b2b-a9f6-e985f54e2005.png)

# %% [markdown]
# ![{B7D5A911-BDAB-485E-9B5D-694784309850}.png](attachment:60647a33-1cfb-466e-b63c-855408c2b4a3.png)

# %%
Drawing a line we could learn that relationship
but the next one not

# %% [markdown]
# ![{F61D4CE6-D984-402E-AE7A-B7C7301050C6}.png](attachment:2c1cf862-9a10-4e42-9a2b-63f3e0a1f146.png)

# %%
Linearity means limited learning power, if the problem can not be properly described as such, as in the first image

# %%
So we need non linear activations to solve this issue, any activations function works as long as it breaks the linearity

# %% [markdown]
# ![{3954BA39-35AF-4A4D-B537-66DA0F528A93}.png](attachment:8d0ae00b-cd6f-4877-8ca2-f6f3a010ac81.png)

# %%
an unlimited number of neurons and non linear activations functions we can approximate any function

# %% [markdown]
# ![{B67AF18C-F9F5-44AD-BC50-F4C51C3A0F2E}.png](attachment:d6fbbcae-bb9c-4ff4-be51-c490e3ab800c.png)

# %%
In this way, we would not gain something because we could simplify the neuron to just one with one weight instead of 2
