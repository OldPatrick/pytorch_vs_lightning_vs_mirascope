# %%
import polars as pl

df = pl.read_csv("student_exam_data.csv")

# %%
df.head()
# Out:
# shape: (5, 3)
# ┌─────────────┬─────────────────────┬───────────┐
# │ Study Hours ┆ Previous Exam Score ┆ Pass/Fail │
# │ ---         ┆ ---                 ┆ ---       │
# │ f64         ┆ f64                 ┆ i64       │
# ╞═════════════╪═════════════════════╪═══════════╡
# │ 4.370861    ┆ 81.889703           ┆ 0         │
# │ 9.556429    ┆ 72.165782           ┆ 1         │
# │ 7.587945    ┆ 58.571657           ┆ 0         │
# │ 6.387926    ┆ 88.827701           ┆ 1         │
# │ 2.404168    ┆ 81.08387            ┆ 0         │
# └─────────────┴─────────────────────┴───────────┘

# %%
import sklearn
from sklearn.metrics import precision_score

# %%
precision_score

# %%
df.plot.scatter(x="Study Hours", y="Previous Exam Score", color="Pass/Fail")
# Out:
# alt.Chart(...)

# %%
# data is not linearly separable

# %%
nn.BCEWithLogitsLoss
