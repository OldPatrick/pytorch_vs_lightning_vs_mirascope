# %%
goal: learn the weights, adjust them

# %%
how does the network works?

1st forward propagation: initial initaite random values or others if you know it better and calculate one prediction

# %% [markdown]
# ![{89D62E12-60E6-4C58-A0D7-03DB906F7BE3}.png](attachment:3d859f3b-1145-401b-9e92-a8a2e4fc15f8.png)

# %%
https://stats.stackexchange.com/questions/376890/is-the-loss-is-the-same-as-the-error-in-deep-learning

# %%
# Predictions vs. actuals for 3 houses:  
predictions = [310, 290, 295]  # Our guesses (in $k)  
actuals =    [300, 300, 300]   # Real prices  

# Errors (per example):  
errors = [310-300, 290-300, 295-300]
print(errors)
# Loss (MSE): Average of squared errors:  
loss = (10**2 + (-10)**2 + (-5)**2) / 3  # = (100 + 100 + 25)/3 = 225/3 = **75**  
print(loss)
# Out:
# [10, -10, -5]
# 75.0
