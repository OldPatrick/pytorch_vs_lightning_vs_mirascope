# %% [markdown]
# ![{C194359F-03E7-4491-9613-8EECE2D10346}.png](attachment:b959d580-6202-4471-b443-29486b063c9e.png)

# %% [markdown]
# ABS würde alle Lösungen gleich innerhalb behandeln, wäre die Linie oben weit an den Punkten wäre diese Lölsung genauso gut wie als wenn die Linie in der Mitte wäre
# MSE behandelt den Abstand von den Punkten zur Linie gleich, wir sind zwar noch off von der Truth aber es ist ein konsistentes Off (Bias), lieber ein wenig immer off als selten aber dafür viel off (letzteres hat wenig konsistenz)
