# %% [markdown]
# ![{6F5F85AE-459B-4E62-AC81-F6035DF45B12}.png](attachment:2805ae7f-7bfc-4710-98fb-3b755ed45993.png)

# %%
how dl works

guess a solution
compute the error and show if it was off or not, and if it was off, how much
but the third point is the hardest learn from mistakes and guess a better solution
need a way to describe the mathematical error landscape

derivative for one dimension problems

for multi dimensional ppl tend to call it gradient but its the same as I pointed out already

# %% [markdown]
# ![{C9830F76-E0CA-42F5-B838-6FCFC6BAE728}.png](attachment:d5aec3c4-d11b-4106-8ec1-96d85d9c64d9.png)

# %% [markdown]
# We want to minimize the function not the derivative, and the function (blue) is minimized (at a global minimum) where the derivative is 0 (the orange) in this case we could compute it with x=0.5<br>
# and if we say X  is -0.5 that would give us -6 and of course not the minimum for the function f(x)
# for example if X= 1.5 the derivative is 5.25 here als a tangens with the function where we want to find the optimum
# Remember f(x) is the y here
# ![{3E97D49C-3529-4AD3-9CB5-0AE78E97AE57}.png](attachment:5239d82d-c08e-41a0-8965-cd8e22fc219f.png)
#
# <br> Gradient descent is not guranteed to give the correct solution and for this example it will give 0.495 which is close but not correct
# But vanishing and exploding gradients is still a problem here

# %% [markdown]
#  - GD is guaranteed to go downhill
#  - it is not guaranteed to find the correct solution or the best solution
#  - it can get stuck in local minima, if parameters are not set right for the error landscape or we had unfortunate starting /init values
#  - error landscapes are hard /impossible to draw in greater > 2D

# %% [markdown]
# ![{4A380DAC-EB68-4BED-B102-E11FE6B7D039}.png](attachment:1733033e-2c74-49f0-8cab-12dd5b59033a.png)

# %% [markdown]
# ![{8F0A495F-7001-4D4E-9D68-4AD223B310CB}.png](attachment:6b2e4e7c-3642-408d-b288-b558c21d9b45.png)
#
# 1D

# %% [markdown]
# we get many models with many similar values /accuracy but very different weights, so why does it perform so well the DL? Because there may be several equally good local minima
# alsodue to the error space there may be only a few good, and when you hit one its fine:
# ![{075CAE2B-937B-4866-9504-A4227974F430}.png](attachment:08b87f49-a778-400d-b10d-72a3232d7f37.png)
# ![{8377E6AD-2BD8-4A67-B315-9C362B65B3B4}.png](attachment:3bcae2fd-e870-4ec4-9b0d-dc0d71e5e679.png)
# ![{65F05CB9-157F-4384-B941-E1EEE96E04F8}.png](attachment:2f58fce8-7864-4924-9598-46a0e7b98842.png)
# here in the graph are no real local minima, only local minimum in one direction

# %% [markdown]
# 400000 params with error functon wit 400k dimensional space all 4000k directions have a minimum in one direction, so maybe local minima are not really a problem

# %% [markdown]
# ![{829AAF46-CA73-4E9B-AB05-E9DD700F0D02}.png](attachment:780a1165-ec1c-4e1c-8a8f-f485ac31c3fc.png)
# increasing complexity means less local minima where all go in one direction, if you found one that fits the model maybe its good, because there are not so much left

# %%
when the learning rate is very small you need more training iterations, model learns more slowly, but otherwise we overshoot
